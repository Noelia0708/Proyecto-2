# %%
import pandas as pd
shark_attack = pd.read_excel("data/tiburones.xls")

# %%
shark_attack
# Out:
#                Date    Year        Type             Country  \
# 0     6th September  2025.0  Unprovoked           Australia
# 1     1st September  2025.0  Unprovoked                 USA
# 2       30th August  2025.0  Unprovoked                 USA
# 3       18th August  2025.0  Unprovoked           Australia
# 4       17th August  2025.0  Unprovoked             Bahamas
# ...             ...     ...         ...                 ...
# 7040    Before 1903     0.0  Unprovoked           AUSTRALIA
# 7041    Before 1903     0.0  Unprovoked           AUSTRALIA
# 7042      1900-1905     0.0  Unprovoked                 USA
# 7043      1883-1889     0.0  Unprovoked              PANAMA
# 7044      1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                                   State                             Location  \
# 0                                   NSW                     Long Reef Sydney
# 1                               Florida             Horseshoe reef Key Largo
# 2                                 Texas                            Galveston
# 3                                   NSW                       Cabarita Beach
# 4     Atlantic Ocean near Big Grand Cay  North of Grand Bahama near Freeport
# ...                                 ...                                  ...
# 7040                  Western Australia                          Roebuck Bay
# 7041                  Western Australia                                  NaN
# 7042                     North Carolina                       Ocracoke Inlet
# 7043                                NaN                 Panama Bay 8ºN, 79ºW
# 7044                   Eastern Province  Below the English fort, Trincomalee
#
#           Activity                   Name Sex  Age  ...  \
# 0          Surfing     Mercury Psillaskis   M   57  ...
# 1       Snorkeling        Richard Burrows   M    8  ...
# 2         Swimming           Harper Ochoa   F    8  ...
# 3          Surfing              Brad Ross   M    ?  ...
# 4     Spearfishing             Not stated   M   63  ...
# ...            ...                    ...  ..  ...  ...
# 7040        Diving                   male   M  NaN  ...
# 7041  Pearl diving                  Ahmun   M  NaN  ...
# 7042      Swimming  Coast Guard personnel   M  NaN  ...
# 7043           NaN        Jules Patterson   M  NaN  ...
# 7044      Swimming                   male   M   15  ...
#
#                      Species   \
# 0           Great White Shark
# 1                  Not stated
# 2                  Not stated
# 3     5m (16.5ft) Great White
# 4                Undetermined
# ...                       ...
# 7040                      NaN
# 7041                      NaN
# 7042                      NaN
# 7043                      NaN
# 7044                      NaN
#
#                                                  Source  \
# 0     Todd Smith: Andy Currie: Simon De Marchi: Kevi...
# 1     Todd Smith: US SUN: NY Post: The Guardian: Peo...
# 2                              Bob Myatt GSAF : People:
# 3     Bob Myatt GSAF The Guardian: 9 News: ABS News:...
# 4     Ralph Collier GSAF and Kevin MCMurray Tracking...
# ...                                                 ...
# 7040                   H. Taunton; N. Bartlett,  p. 234
# 7041              H. Taunton; N. Bartlett,  pp. 233-234
# 7042               F. Schwartz, p.23; C. Creswell, GSAF
# 7043                                The Sun, 10/20/1938
# 7044                                         S.W. Baker
#
#                                  pdf  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 7040          ND-0005-RoebuckBay.pdf
# 7041               ND-0004-Ahmun.pdf
# 7042  ND-0003-Ocracoke_1900-1905.pdf
# 7043      ND-0002-JulesPatterson.pdf
# 7044              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7041  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7042  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7043  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7044  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 7041  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 7042  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 7043  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 7044  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 1              NaN            NaN         NaN         NaN
# 2              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 4              NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 7040       ND.0005            6.0         NaN         NaN
# 7041       ND.0004            5.0         NaN         NaN
# 7042       ND.0003            4.0         NaN         NaN
# 7043       ND.0002            3.0         NaN         NaN
# 7044       ND.0001            2.0         NaN         NaN
#
# [7045 rows x 23 columns]

# %%
shark_attack.drop('Location', axis =1, inplace=True)
shark_attack.drop('Name', axis =1, inplace=True)
shark_attack.drop('Sex', axis =1, inplace=True)
shark_attack.drop('Age', axis =1, inplace=True)
shark_attack.drop('Injury', axis =1, inplace=True)
shark_attack.drop('Time', axis =1, inplace=True)
shark_attack.drop('Source', axis =1, inplace=True)
shark_attack.drop('pdf', axis =1, inplace=True)
shark_attack.drop('href formula', axis =1, inplace=True)
shark_attack.drop('href', axis =1, inplace=True)
shark_attack.drop('Case Number', axis =1, inplace=True)
shark_attack.drop('Case Number.1', axis =1, inplace=True)
shark_attack.drop('original order', axis =1, inplace=True)
shark_attack.drop('Unnamed: 21', axis =1, inplace=True)
shark_attack.drop('Unnamed: 22', axis =1, inplace=True)

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7045 entries, 0 to 7044
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7045 non-null   object
#  1   Year       7043 non-null   float64
#  2   Type       7027 non-null   object
#  3   Country    6995 non-null   object
#  4   State      6560 non-null   object
#  5   Activity   6460 non-null   object
#  6   Fatal Y/N  6484 non-null   object
#  7   Species    3914 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.4+ KB

# %%
shark_attack
# Out:
#                Date    Year        Type             Country  \
# 0     6th September  2025.0  Unprovoked           Australia
# 1     1st September  2025.0  Unprovoked                 USA
# 2       30th August  2025.0  Unprovoked                 USA
# 3       18th August  2025.0  Unprovoked           Australia
# 4       17th August  2025.0  Unprovoked             Bahamas
# ...             ...     ...         ...                 ...
# 7040    Before 1903     0.0  Unprovoked           AUSTRALIA
# 7041    Before 1903     0.0  Unprovoked           AUSTRALIA
# 7042      1900-1905     0.0  Unprovoked                 USA
# 7043      1883-1889     0.0  Unprovoked              PANAMA
# 7044      1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                                   State      Activity Fatal Y/N  \
# 0                                   NSW       Surfing         Y
# 1                               Florida    Snorkeling         N
# 2                                 Texas      Swimming         N
# 3                                   NSW       Surfing         N
# 4     Atlantic Ocean near Big Grand Cay  Spearfishing         N
# ...                                 ...           ...       ...
# 7040                  Western Australia        Diving         Y
# 7041                  Western Australia  Pearl diving         Y
# 7042                     North Carolina      Swimming         Y
# 7043                                NaN           NaN         Y
# 7044                   Eastern Province      Swimming         Y
#
#                      Species
# 0           Great White Shark
# 1                  Not stated
# 2                  Not stated
# 3     5m (16.5ft) Great White
# 4                Undetermined
# ...                       ...
# 7040                      NaN
# 7041                      NaN
# 7042                      NaN
# 7043                      NaN
# 7044                      NaN
#
# [7045 rows x 8 columns]

# %%
shark_attack.nunique()
# Out:
# Date         6089
# Year          261
# Type           13
# Country       247
# State         937
# Activity     1606
# Fatal Y/N      12
# Species      1724
# dtype: int64

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7045 entries, 0 to 7044
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7045 non-null   object
#  1   Year       7043 non-null   float64
#  2   Type       7027 non-null   object
#  3   Country    6995 non-null   object
#  4   State      6560 non-null   object
#  5   Activity   6460 non-null   object
#  6   Fatal Y/N  6484 non-null   object
#  7   Species    3914 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.4+ KB

# %%
shark_attack
# Out:
#                Date    Year        Type             Country  \
# 0     6th September  2025.0  Unprovoked           Australia
# 1     1st September  2025.0  Unprovoked                 USA
# 2       30th August  2025.0  Unprovoked                 USA
# 3       18th August  2025.0  Unprovoked           Australia
# 4       17th August  2025.0  Unprovoked             Bahamas
# ...             ...     ...         ...                 ...
# 7040    Before 1903     0.0  Unprovoked           AUSTRALIA
# 7041    Before 1903     0.0  Unprovoked           AUSTRALIA
# 7042      1900-1905     0.0  Unprovoked                 USA
# 7043      1883-1889     0.0  Unprovoked              PANAMA
# 7044      1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                                   State      Activity Fatal Y/N  \
# 0                                   NSW       Surfing         Y
# 1                               Florida    Snorkeling         N
# 2                                 Texas      Swimming         N
# 3                                   NSW       Surfing         N
# 4     Atlantic Ocean near Big Grand Cay  Spearfishing         N
# ...                                 ...           ...       ...
# 7040                  Western Australia        Diving         Y
# 7041                  Western Australia  Pearl diving         Y
# 7042                     North Carolina      Swimming         Y
# 7043                                NaN           NaN         Y
# 7044                   Eastern Province      Swimming         Y
#
#                      Species
# 0           Great White Shark
# 1                  Not stated
# 2                  Not stated
# 3     5m (16.5ft) Great White
# 4                Undetermined
# ...                       ...
# 7040                      NaN
# 7041                      NaN
# 7042                      NaN
# 7043                      NaN
# 7044                      NaN
#
# [7045 rows x 8 columns]

# %%
shark_attack = shark_attack[shark_attack['Year'] > 1970]

# %%
shark_attack
# Out:
#                Date    Year        Type    Country  \
# 0     6th September  2025.0  Unprovoked  Australia
# 1     1st September  2025.0  Unprovoked        USA
# 2       30th August  2025.0  Unprovoked        USA
# 3       18th August  2025.0  Unprovoked  Australia
# 4       17th August  2025.0  Unprovoked    Bahamas
# ...             ...     ...         ...        ...
# 4097           1971  1971.0  Unprovoked  AUSTRALIA
# 4098           1971  1971.0  Unprovoked    CROATIA
# 4099           1971  1971.0  Unprovoked       IRAN
# 4100           1971  1971.0  Unprovoked       IRAN
# 4615    16-Jul-1961  1971.0  Unprovoked     TURKEY
#
#                                   State      Activity Fatal Y/N  \
# 0                                   NSW       Surfing         Y
# 1                               Florida    Snorkeling         N
# 2                                 Texas      Swimming         N
# 3                                   NSW       Surfing         N
# 4     Atlantic Ocean near Big Grand Cay  Spearfishing         N
# ...                                 ...           ...       ...
# 4097                    South Australia       Surfing         N
# 4098                            Istria       Swimming       NaN
# 4099                 Khuzestan Province           NaN         N
# 4100                 Khuzestan Province           NaN         N
# 4615                           Anatolia      Swimming         N
#
#                      Species
# 0           Great White Shark
# 1                  Not stated
# 2                  Not stated
# 3     5m (16.5ft) Great White
# 4                Undetermined
# ...                       ...
# 4097              White shark
# 4098              White shark
# 4099                      NaN
# 4100                      NaN
# 4615                      NaN
#
# [4100 rows x 8 columns]

# %%
shark_attack['Fatal Y/N'] = shark_attack['Fatal Y/N'].replace({'Y': 1, 'N': 0})
# Out:
# C:\Users\luisf\AppData\Local\Temp\ipykernel_13068\2626908745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attack['Fatal Y/N'] = shark_attack['Fatal Y/N'].replace({'Y': 1, 'N': 0})

# %%
shark_attack
# Out:
#                Date    Year        Type    Country  \
# 0     6th September  2025.0  Unprovoked  Australia
# 1     1st September  2025.0  Unprovoked        USA
# 2       30th August  2025.0  Unprovoked        USA
# 3       18th August  2025.0  Unprovoked  Australia
# 4       17th August  2025.0  Unprovoked    Bahamas
# ...             ...     ...         ...        ...
# 4097           1971  1971.0  Unprovoked  AUSTRALIA
# 4098           1971  1971.0  Unprovoked    CROATIA
# 4099           1971  1971.0  Unprovoked       IRAN
# 4100           1971  1971.0  Unprovoked       IRAN
# 4615    16-Jul-1961  1971.0  Unprovoked     TURKEY
#
#                                   State      Activity Fatal Y/N  \
# 0                                   NSW       Surfing         1
# 1                               Florida    Snorkeling         0
# 2                                 Texas      Swimming         0
# 3                                   NSW       Surfing         0
# 4     Atlantic Ocean near Big Grand Cay  Spearfishing         0
# ...                                 ...           ...       ...
# 4097                    South Australia       Surfing         0
# 4098                            Istria       Swimming       NaN
# 4099                 Khuzestan Province           NaN         0
# 4100                 Khuzestan Province           NaN         0
# 4615                           Anatolia      Swimming         0
#
#                      Species
# 0           Great White Shark
# 1                  Not stated
# 2                  Not stated
# 3     5m (16.5ft) Great White
# 4                Undetermined
# ...                       ...
# 4097              White shark
# 4098              White shark
# 4099                      NaN
# 4100                      NaN
# 4615                      NaN
#
# [4100 rows x 8 columns]

# %%
grouped = shark_attack.groupby('Fatal Y/N')

# %%
grouped.size()
# Out:
# Fatal Y/N
# 0          3323
# 1           466
# 2017          1
# F             5
# M             3
# Nq            1
# UNKNOWN      25
# Y x 2         1
# n             1
# dtype: int64

# %%
shark_attack['Country'].mode()
# Out:
# 0    USA
# Name: Country, dtype: object

# %%
grouped_2 = shark_attack.groupby('Country')

# %%
grouped_2.size()
# Out:
# Country
#  TONGA            3
# ANGOLA            1
# ANTIGUA           1
# ARGENTINA         1
# ARUBA             1
#                  ..
# VENEZUELA         7
# VIETNAM          10
# Vanuatu           1
# WESTERN SAMOA     1
# YEMEN             1
# Length: 156, dtype: int64

# %%
grouped_2.size().max()
# Out:
# np.int64(1925)

# %%
shark_attack['State'].mode()
# Out:
# 0    Florida
# Name: State, dtype: object

# %%
shark_attack['Country'] = shark_attack['Country'].str.lower().str.strip()
shark_attack['State'] = shark_attack['State'].str.upper().str.strip()
shark_attack['Activity'] = shark_attack['Activity'].str.lower().str.strip()
shark_attack['Type'] = shark_attack['Type'].str.lower().str.strip()
# Out:
# C:\Users\luisf\AppData\Local\Temp\ipykernel_13068\4066221363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attack['Country'] = shark_attack['Country'].str.lower().str.strip()
# C:\Users\luisf\AppData\Local\Temp\ipykernel_13068\4066221363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attack['State'] = shark_attack['State'].str.upper().str.strip()
# C:\Users\luisf\AppData\Local\Temp\ipykernel_13068\4066221363.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attack['Activity'] = shark_attack['Activity'].str.lower().str.strip()
# C:\Users\luisf\AppData\Local\Temp\ipykernel_13068\4066221363.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_attack['Type'] = shark_attack['Type'].str.lower().str.strip()

# %%
shark_attack
# Out:
#                Date    Year        Type    Country  \
# 0     6th September  2025.0  unprovoked  australia
# 1     1st September  2025.0  unprovoked        usa
# 2       30th August  2025.0  unprovoked        usa
# 3       18th August  2025.0  unprovoked  australia
# 4       17th August  2025.0  unprovoked    bahamas
# ...             ...     ...         ...        ...
# 4097           1971  1971.0  unprovoked  australia
# 4098           1971  1971.0  unprovoked    croatia
# 4099           1971  1971.0  unprovoked       iran
# 4100           1971  1971.0  unprovoked       iran
# 4615    16-Jul-1961  1971.0  unprovoked     turkey
#
#                                   State      Activity Fatal Y/N  \
# 0                                   NSW       surfing         1
# 1                               FLORIDA    snorkeling         0
# 2                                 TEXAS      swimming         0
# 3                                   NSW       surfing         0
# 4     ATLANTIC OCEAN NEAR BIG GRAND CAY  spearfishing         0
# ...                                 ...           ...       ...
# 4097                    SOUTH AUSTRALIA       surfing         0
# 4098                             ISTRIA      swimming       NaN
# 4099                 KHUZESTAN PROVINCE           NaN         0
# 4100                 KHUZESTAN PROVINCE           NaN         0
# 4615                           ANATOLIA      swimming         0
#
#                      Species
# 0           Great White Shark
# 1                  Not stated
# 2                  Not stated
# 3     5m (16.5ft) Great White
# 4                Undetermined
# ...                       ...
# 4097              White shark
# 4098              White shark
# 4099                      NaN
# 4100                      NaN
# 4615                      NaN
#
# [4100 rows x 8 columns]

# %%
shark_attack['Country'].value_counts().head(10)
# Out:
# Country
# usa              1925
# australia         737
# south africa      382
# bahamas           113
# brazil            113
# new zealand        74
# new caledonia      57
# mexico             56
# reunion            56
# egypt              37
# Name: count, dtype: int64

# %%
shark_attack.isna().sum()
# Out:
# Date            0
# Year            0
# Type           14
# Country         3
# State         171
# Activity      241
# Fatal Y/N     274
# Species      1452
# dtype: int64

# %%
shark_attack['State'].value_counts().head(10)
# Out:
# State
# FLORIDA                  995
# HAWAII                   253
# CALIFORNIA               239
# NEW SOUTH WALES          230
# QUEENSLAND               174
# WESTERN AUSTRALIA        166
# WESTERN CAPE PROVINCE    139
# EASTERN CAPE PROVINCE    126
# SOUTH CAROLINA           123
# KWAZULU-NATAL            103
# Name: count, dtype: int64
